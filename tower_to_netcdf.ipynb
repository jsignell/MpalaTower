# %% [markdown]
# # Convert Flux Tower Time Series data CSV file to NetCDF CF-1.6 timeSeries file

# %%
import numpy as np
import pandas as pd
import netCDF4
import re
import os
import urllib
import xray
import zipfile
import datetime as dt
import shutil
import dateutil
# %matplotlib inline

# %%
ROOTDIR = "C:/Users/Julia/Dropbox (PE)/netcdfDevelopment/netcdf/"
DATALOC = "C:/Users/Julia/Dropbox (PE)/KenyaLab/Data/Tower/TowerDataArchive/test/"
NETCDFLOC = "C:/Users/Julia/Dropbox (PE)/netcdfDevelopment/netcdf/output/"
input_file=DATALOC+'CR5000_SN2446_upper_2010_02_09.dat'
output_file=NETCDFLOC+"CR5000_SN2446_upper.nc"

# %%
station_name = 'MPALA Tower'
lon = 36.9   # degrees east
lat = 0.5    # degrersityes north
timezone = +0300 #Africa/Nairobi
    
# add highly recommended metadata from:
# http://wiki.esipfed.org/index.php/Attribute_Convention_for_Data_Discovery_1-3#Highly_Recommended
title = 'Flux Tower Data from MPALA'
summary = 'This raw data comes from the MPALA Flux Tower, which is maintained by the Ecohydrology Lab at Mpala Research Centre in Laikipia, Kenya. It is part of a long-term monitoring project that was originally funded by NSF and now runs with support from Princeton. It’s focus is on using stable isotopes to better understand water balance in drylands, particularly transpiration and evaporation fluxes.'
license = 'MIT License'   # see choosealicense.com.   You can also make up your own and just say what the license is
institution = 'Princeton University'
acknowledgement = 'Funded by NSF and Princeton University'
naming_authority= 'caylor.princeton.edu'
dset_id = station_name
creator_name = 'Kelly Caylor'
creator_email = 'kcaylor@princeton.edu'
keywords = ['eddy covariance','isotope hydrology', 'land surface flux']

# %%
df = pd.read_csv(input_file,skiprows=[0,2,3],parse_dates=True,index_col=0,low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-b14270fdfc96> in <module>()
# ----> 1 df = pd.read_csv(input_file,skiprows=[0,2,3],parse_dates=True,index_col=0,low_memory=False, date_parser=date_ea)
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     461                     skip_blank_lines=skip_blank_lines)
#     462
# --> 463         return _read(filepath_or_buffer, kwds)
#     464
#     465     parser_f.__name__ = name
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\parsers.pyc in _read(filepath_or_buffer, kwds)
#     247         return parser
#     248
# --> 249     return parser.read()
#     250
#     251 _parser_defaults = {
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\parsers.pyc in read(self, nrows)
#     704                 raise ValueError('skip_footer not supported for iteration')
#     705
# --> 706         ret = self._engine.read(nrows)
#     707
#     708         if self.options.get('as_recarray'):
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\parsers.pyc in read(self, nrows)
#    1201
#    1202             names, data = self._do_date_conversions(names, data)
# -> 1203             index, names = self._make_index(data, alldata, names)
#    1204
#    1205         # maybe create a mi on the columns
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\parsers.pyc in _make_index(self, data, alldata, columns, indexnamerow)
#     872         elif not self._has_complex_date_col:
#     873             index = self._get_simple_index(alldata, columns)
# --> 874             index = self._agg_index(index)
#     875
#     876         elif self._has_complex_date_col:
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\parsers.pyc in _agg_index(self, index, try_parse_dates)
#     953
#     954             if (try_parse_dates and self._should_parse_dates(i)):
# --> 955                 arr = self._date_conv(arr)
#     956
#     957             col_na_values = self.na_values
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\parsers.pyc in converter(*date_cols)
#    2034                                                dayfirst=dayfirst)
#    2035                 except Exception:
# -> 2036                     return generic_parser(date_parser, *date_cols)
#    2037
#    2038     return converter
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\io\date_converters.pyc in generic_parser(parse_func, *cols)
#      36     for i in range(N):
#      37         args = [c[i] for c in cols]
# ---> 38         results[i] = parse_func(*args)
#      39
#      40     return results
#
# <ipython-input-64-2781c4dc39d8> in date_ea(s)
#       3
#       4 def date_ea(s):
# ----> 5     return parse(s, tzinfos=ea)
#       6
#       7 df = read_csv('my.csv', parse_dates=[0], date_parser=date_utc)
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\dateutil\parser.pyc in parse(timestr, parserinfo, **kwargs)
#     746         return parser(parserinfo).parse(timestr, **kwargs)
#     747     else:
# --> 748         return DEFAULTPARSER.parse(timestr, **kwargs)
#     749
#     750
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\dateutil\parser.pyc in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     322             ret = ret+relativedelta.relativedelta(weekday=res.weekday)
#     323         if not ignoretz:
# --> 324             if isinstance(tzinfos, collections.Callable) or tzinfos and res.tzname in tzinfos:
#     325                 if isinstance(tzinfos, collections.Callable):
#     326                     tzdata = tzinfos(res.tzname, res.tzoffset)
#
# TypeError: argument of type 'tzfile' is not iterable

# %%
# group dataframe by day of the year
DFList = []
for group in df.groupby([df.index.year,df.index.month,df.index.day]):
    DFList.append(group[1])

# %%
#create the output filenames
ncfilename = []
for i in range(len(DFList)):
    doy = DFList[i].index[0].dayofyear
    y = DFList[i].index[0].year
    ncfilename.append('raw_MpalaTower_%i_%03d.nc' %(y,doy))

# %%
""" to read in chunks instead:
reader = pd.read_csv(file,skiprows=[0,2,3],parse_dates=True,index_col=0,chunksize=2000)
for chunk in reader:
    <write chunk to netcdf>
""";

# %%
# in this CSV file, some metadata were written in the 1st row
df_meta = pd.read_csv(input_file,nrows=1)
meta=list(df_meta.columns.values)

# %%
# use the 2nd item in list as instrument
instrument = meta[1]
source = 'Flux tower sensor data %s, %s, %s' % (meta[1],meta[5],meta[6])

# %%
# in this CSV file, the units were written in the 3rd row
df_units = pd.read_csv(input_file,skiprows=[0,1],nrows=1)
unit_names = list(df_units.columns.values)

# %%
# in this CSV file, the measurement types were written in the 4th row
df_types = pd.read_csv(input_file,skiprows=[0,1,2],nrows=1)
type_names = list(df_types.columns.values)

# %%
def pd_to_secs(df):
    """
    convert a pandas datetime index to "seconds since 1970-01-01 00:00"
    """
    import calendar
    return np.asarray([ calendar.timegm(x.timetuple()) for x in df.index ], dtype=np.int64)

# %%
i=0
for df_day in DFList:
    output_file = NETCDFLOC+ ncfilename[i]
    i+=1
    ntime,ncols = np.shape(df_day)
    #create NetCDF file
    nc = netCDF4.Dataset(output_file,mode='w',clobber=True)
    # add some global attributes
    nc.Conventions='CF-1.6'
    nc.featureType='timeSeries'
    nc.title=title
    nc.summary=summary
    nc.license=license
    nc.institution=institution
    nc.acknowledgement = acknowledgement
    nc.naming_authority = naming_authority
    nc.id = dset_id 
    nc.creator_name = creator_name
    nc.creator_email = creator_email
    nc.instrument = instrument
    nc.source = source
    #create time dimension
    nc.createDimension('time',ntime)    # create fixed time dimension
    #nc.createDimension('time',None)     # create unlimited time dimension (for appending more data later)
    # create dimension for station_name 
    nchar_max=len(station_name)
    nc.createDimension('name_strlen',nchar_max);
    #Create time,lon,lat,altitude variables
    tvar = nc.createVariable('time','f8',dimensions=('time'))
    tvar.units='seconds since 1970-01-01 00:00 +00:00'
    tvar.standard_name='time'
    tvar.calendar='gregorian'
    #create timeseries_id variable
    stavar = nc.createVariable('station_name','S1',dimensions=('name_strlen'))
    stavar.long_name = 'station name'
    stavar.cf_role='timeseries_id'
    lonvar = nc.createVariable('lon','f4')
    lonvar.units = 'degrees east'
    lonvar.standard_name = 'longitude'
    latvar = nc.createVariable('lat','f4')
    latvar.units = 'degrees north'
    latvar.standard_name = 'latitude'
    evar = nc.createVariable('elevation','f4')
    evar.units = 'm'
    evar.standard_name = 'height'
    evar.positive = 'up'
    evar.axis='Z'
    #create variables from CSV file 
    var_names = list(df_day.columns.values)
    var=[]
    # the first 10 columns have time values, not data, so start in 11th column [10]
    startcol=1
    for var_name in var_names[startcol:]:
        var_name = re.sub('[)()]', '_', var_name)    # netcdf doesn't like var names like "temp(17)", but "temp_17_" is okay.
        var.append(nc.createVariable(var_name,'f4',dimensions=('time'),zlib=True, complevel=4))
    #add attributes to variables from CSV file
    k=startcol
    for v in var:
        v.units = (re.sub('[.]',':',unit_names[k])).split(':')[0]     # units like "deg C.17" or "deg C:17" should just be "deg C"
        v.comment = (re.sub('[.]',':',type_names[k])).split(':')[0]
        v.coordinates = 'time lon lat elevation'
        v.content_coverage_type= 'physicalMeasurement'
        k+=1
    # write lon,lat, elevation and station id
    lonvar[0]=lon
    latvar[0]=lat
    evar[0]=height
    stavar[:]=netCDF4.stringtoarr(station_name,nchar_max)
    #write time values
    tvar[:]=pd_to_secs(df_day)
    #Write data from CSV to NetCDF
    k=startcol
    for v in var:
        v[:]=df_day.iloc[:,k].values
        k+=1
    nc.close()

# %%
# just a test to make sure data in the dataFrame look okay
df.iloc[:5,10:15]
# Out:
#                      Day_of_Year  Tsoil10cmTree_Avg  Tsoil20cmTree_Avg  \
# TIMESTAMP
# 2012-12-21 16:30:00          356              19.78              20.42
# 2012-12-21 16:40:00          356              19.81              20.45
# 2012-12-21 16:50:00          356              19.84              20.47
# 2012-12-21 17:00:00          356              19.86              20.49
# 2012-12-21 17:10:00          356              19.89              20.51
#
#                      Tsoil10cmGrass_Avg  Tsoil20cmGass_Avg
# TIMESTAMP
# 2012-12-21 16:30:00               21.50              20.74
# 2012-12-21 16:40:00               21.55              20.79
# 2012-12-21 16:50:00               21.60              20.83
# 2012-12-21 17:00:00               21.64              20.88
# 2012-12-21 17:10:00               21.68              20.92

# %%
#just a test to make sure the data in dataFrame looks okay
df[['Tsoil10cmTree_Avg','Tsoil20cmTree_Avg']].plot(figsize=(12,4));

# %%
# Test: read just one variable from the NetCDF file using Iris

# %%
import iris
from iris.pandas import as_cube, as_series, as_data_frame
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-74bccfc61709> in <module>()
#       1 import iris
# ----> 2 from iris.pandas import as_cube, as_series, as_data_frame
#
# ImportError: No module named pandas

# %%
c = iris.load_cube(output_file,'Tsoil10cmTree_Avg')

# %%
df = as_series(c)

# %%
df.plot(figsize=(12,4));

# %%
DATAFILERE = re.compile('^CR\d{4}_SN\d+_(.*?)\.dat$')
for f in os.listdir(DATALOC):
    if DATAFILERE.match(f):
        print f
# Out:
# CR1000_SN7276_Manifold.dat
# CR3000_SN4709_flux.dat
# CR3000_SN4709_WVIA.dat
# CR3000_SN5355_Table1.dat
# CR5000_SN2446_lws.dat
# CR5000_SN2446_upper.dat

# %%
l = []
list_elements = []
to_merge = []
index = []
for i in os.walk(NETCDFLOC):
    l.append(i)
for folder in l:
    for elements in folder[2]: 
        list_elements.append(elements)
for element in set(list_elements):
    index.append(element.partition('MpalaTower_')[2].partition('.nc')[0])
    if list_elements.count(element)>=2:
        to_merge.append(element)
        print element, 'occurs in', list_elements.count(element), 'out of 8 possible'
columns = l[0][1]
index.sort()
to_merge.sort()
# Out:
# raw_MpalaTower_2014_318.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_319.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_325.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_321.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_329.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_324.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_326.nc occurs in 6 out of 8 possible
# raw_MpalaTower_2014_327.nc occurs in 6 out of 8 possible
# raw_MpalaTower_2014_323.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_320.nc occurs in 5 out of 8 possible
# raw_MpalaTower_2014_328.nc occurs in 6 out of 8 possible
# raw_MpalaTower_2014_322.nc occurs in 5 out of 8 possible

# %%
l = []
for i in os.walk(NETCDFLOC):
    l.append(i)
columns = l[0][1]
todays_date = datetime.datetime.now().date()
first_date= datetime.datetime(2010,01,01).date()
index = pd.date_range(start =first_date, end = todays_date, freq='D',tz = 'Africa/Nairobi')
df_ = pd.DataFrame(index=index, columns=columns)
df_ = df_.fillna(' ') # with 0s rather than NaNs
for day in range(len(df_.index)):
    doy = df_.index[day].timetuple().tm_yday
    y = df_.index[day].year
    filename = 'raw_MpalaTower_%d_%03d.nc'%(y,doy)
    for folder in l:
        if filename in folder[2]:
            column = folder[0].partition('output/')[2]
            df_[column][df_.index[day]]=True
df_.to_csv(NETCDFLOC+'SummaryTable.csv')

# %%
ds = xray.open_dataset("C:/Users/Julia/Dropbox (PE)/netcdfDevelopment/netcdf/output/lws/raw_MpalaTower_2014_319.nc", decode_times = True)

# %%
ds1 = xray.open_dataset("C:/Users/Julia/Dropbox (PE)/netcdfDevelopment/netcdf/output/lws/raw_MpalaTower_2014_320.nc", decode_times = True)

# %%
l = []
FILEDIR = "C:/Users/Julia/Dropbox (PE)/netcdfDevelopment/netcdf/output/lws/"
for i in range(366):
    if 'raw_MpalaTower_2014_%03d.nc'%i in os.listdir(FILEDIR):
        l.append(xray.open_dataset(FILEDIR+'raw_MpalaTower_2014_%03d.nc'%i, decode_times = True))

# %%
k = l[1:17]

# %%
len(k)
# Out:
# 16

# %%
ds = xray.concat(k, dim = 'time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-10a7a87d00f5> in <module>()
# ----> 1 ds = xray.concat(k, dim = 'time')
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\xray\core\alignment.pyc in concat(objs, dim, indexers, mode, concat_over, compat)
#     236         raise ValueError('must supply at least one object to concatenate')
#     237     cls = type(first_obj)
# --> 238     return cls._concat(objs, dim, indexers, mode, concat_over, compat)
#     239
#     240
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\xray\core\dataset.pyc in _concat(cls, datasets, dim, indexers, mode, concat_over, compat)
#    1494         for k in concat_over:
#    1495             concatenated[k] = variable.Variable.concat(
# -> 1496                 [ds[k] for ds in datasets], dim, indexers)
#    1497
#    1498         concatenated._coord_names.update(datasets[0].coords)
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\xray\core\dataset.pyc in __setitem__(self, key, value)
#     620         variable.
#     621         """
# --> 622         self.merge({key: value}, inplace=True, overwrite_vars=[key])
#     623
#     624     def __delitem__(self, key):
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\xray\core\dataset.pyc in merge(self, other, inplace, overwrite_vars, compat)
#    1107         obj = self if inplace else self.copy()
#    1108         obj._update_vars_and_coords(new_variables, new_coord_names,
# -> 1109                                     needs_copy=inplace)
#    1110         return obj
#    1111
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\xray\core\dataset.pyc in _update_vars_and_coords(self, new_arrays, new_coord_names, needs_copy, check_coord_names)
#     378
#     379         arrays.update(new_arrays)
# --> 380         dims = _calculate_dims(arrays)
#     381         # all checks are complete: it's safe to update
#     382         self._arrays = arrays
#
# C:\Users\Julia\AppData\Local\Enthought\Canopy\User\lib\site-packages\xray\core\dataset.pyc in _calculate_dims(variables)
#     227                 raise ValueError('conflicting sizes for dimension %r: '
#     228                                  'length %s on %r and length %s on %r' %
# --> 229                                  (dim, size, k, dims[dim], last_used[dim]))
#     230     return dims
#     231
#
# ValueError: conflicting sizes for dimension 'time': length 16 on u'lon' and length 23040 on u'LWMCon_4_Tot'

# %%
ds2.dims
# Out:
# Frozen(SortedKeysDict({u'time': 2880L}))

# %%
ds1.dims
# Out:
# Frozen(SortedKeysDict({u'time': 1440}))

# %%
1440*18
# Out:
# 25920

# %%
ds2.to_netcdf(
